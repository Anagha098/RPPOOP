# %%
#Hierarchial Inheritance
import math
class polygon():
    def __init__(self,side,sides):
        self.side = length
        self.sides = n
    def perimeter(self):
        return self.sides*self.side
    def area(self):
        return (self.side**2)*self.sides/(4*math.tan(math.pi/self.sides))
    
class triangle(polygon):
    def __init__(self,side):
        self.sides = 3
        self.side = length

class square(polygon):
    def __init__(self,side):
        self.sides = 4
        self.side = length
        
class pentagon(polygon):
    def __init__(self,side):
        self.sides = 5
        self.side = length
        
#tri = triangle(2)
#squ = square(2)
#pent = pentagon(2)

while 1>0 :
    print("Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.")
    choice = int(input())
    if choice == 1:
        print("Enter the length of side : \n")
        length = int(input())
        tri = triangle(length)
        print("Perimeter = \n")
        print(tri.perimeter())
        print("Area = \n")
        print(tri.area())
    elif choice == 2:
        print("Enter the length of side : \n")
        length = int(input())
        squ = square(length)
        print("Perimeter = \n")
        print(squ.perimeter())
        print("Area = \n")
        print(squ.area())
    elif choice == 3:
        print("Enter the length of side : \n")
        length = int(input())
        pent = pentagon(length)
        print("Perimeter = \n")
        print(pent.perimeter())
        print("Area = \n")
        print(pent.area())
    elif choice == 4:
        print("Exiting\n")
        break
    else :
        print("Invalid output\n")
# Out:
# Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.
# 1
# Enter the length of side :
#
# 4
# Perimeter =
#
# 12
# Area =
#
# 6.928203230275511
# Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.
# 2
# Enter the length of side :
#
# 4
# Perimeter =
#
# 16
# Area =
#
# 16.000000000000004
# Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.
# 3
# Enter the length of side :
#
# 4
# Perimeter =
#
# 20
# Area =
#
# 27.52763840942347
# Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.
# 5
# Invalid output
#
# Enter 1 for triangle, 2 for square, 3 for pentagon, 4 to exit.
# 4
# Exiting

# %%
#Single Inheritance
import math
class polygon():
    def __init__(self,side,sides):
        self.side = length
        self.sides = n
    def perimeter(self):
        return self.sides*self.side
    def area(self):
        return (self.side**2)*self.sides/(4*math.tan(math.pi/self.sides))
    
class triangle(polygon):
    def __init__(self,side,sides):
        self.side = length
        self.sides = 3
    

print("Enter the length of side : \n")
length = int(input())
tri = triangle(length)
print("Perimeter = \n")
print(tri.perimeter())
print("Area = \n")
print(tri.area())
